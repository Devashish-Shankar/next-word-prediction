# %%
import sys
import os

sys.path.append(
    os.path.abspath("..")
)

# %%
from src.inference.predict import Predictor

# %%
predictor = Predictor(
    "../models/lstm_checkpoint.pth"
)

# %%
predictor.predict_next_word(
    "the united"
)
# Out:
# 'nations'

# %%
predictor.predict_next_word(
    "machine learning"
)
# Out:
# ','

# %%
predictor.predict_next_word(
    "artificial intelligence"
)
# Out:
# 'on'

# %%
predictor.predict_next_word(
    "I want to learn artificial"
)
# Out:
# 'live'
