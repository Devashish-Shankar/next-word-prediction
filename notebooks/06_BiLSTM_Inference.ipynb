# %%
import sys
import os

sys.path.append(
    os.path.abspath("..")
)

# %%
from src.inference.bilstm_predict import BiLSTMPredictor

# %%
predictor = BiLSTMPredictor()

# %%
predictor.predict_top_k(
    "machine learning"
)
# Out:
# [('in', 0.30936431884765625),
#  ('as', 0.27225255966186523),
#  (',', 0.13075731694698334),
#  ('that', 0.10386825352907181),
#  ('during', 0.06820280104875565)]

# %%
predictor.predict_top_k(
    "artificial intelligence"
)
# Out:
# [('in', 0.2931760549545288),
#  ('from', 0.18647004663944244),
#  ('on', 0.15702517330646515),
#  ('ones', 0.07034071534872055),
#  ('as', 0.040372300893068314)]

# %%
predictor.predict_top_k(
    "the united"
)
# Out:
# [('grant', 0.1973825842142105),
#  ('states', 0.11964873224496841),
#  ('cover', 0.11126886308193207),
#  ('performances', 0.10087832063436508),
#  ('service', 0.05200633406639099)]
